# %% [markdown]
# ## Importing hr_data file

# %%
import pandas as pd
hr_df = pd.read_csv(r'C:\Users\Anupama Jadhav\Downloads\Loyalty of Employees\Loyall\Predict Loyall\hr_data.csv')

# %%
hr_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
# [14999 rows x 9 columns]

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.size
# Out:
# 134991

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
hr_df['average_montly_hours'].unique()
# Out:
# array([157, 262, 272, 223, 159, 153, 247, 259, 224, 142, 135, 305, 234,
#        148, 137, 143, 160, 255, 282, 147, 304, 139, 158, 242, 239, 128,
#        132, 294, 134, 145, 140, 246, 126, 306, 152, 269, 127, 281, 276,
#        182, 273, 307, 309, 225, 226, 308, 244, 286, 161, 264, 277, 275,
#        149, 295, 151, 249, 291, 232, 130, 129, 155, 265, 279, 284, 221,
#        154, 150, 267, 257, 177, 144, 289, 258, 263, 251, 133, 216, 300,
#        138, 260, 183, 250, 292, 283, 245, 256, 278, 240, 136, 301, 243,
#        296, 274, 164, 146, 261, 285, 141, 297, 156, 287, 219, 254, 228,
#        131, 252, 236, 270, 298, 192, 248, 266, 238, 229, 233, 268, 231,
#        253, 302, 271, 290, 235, 293, 241, 218, 199, 180, 195, 237, 227,
#        172, 206, 181, 217, 310, 214, 198, 211, 222, 213, 202, 184, 204,
#        288, 220, 299, 303, 212, 196, 179, 205, 230, 203, 280, 169, 188,
#        178, 175, 166, 163, 168, 165, 189, 162, 215, 193, 176, 191, 174,
#        201, 208, 171, 111, 104, 106, 100, 194, 209, 185, 200, 207, 187,
#        210, 186, 167, 108, 122, 110, 115, 197, 102, 109, 190,  99, 101,
#         97, 173, 121, 170, 105, 118, 119, 117, 114,  96,  98, 107, 123,
#        116, 125, 113, 120, 112, 124, 103], dtype=int64)

# %%
hr_df['promotion_last_5years'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ## Loading Satisfaction Dataset  ( ie. employee_satisfaction_evaluation file)

# %%
s_df = pd.read_excel(r'C:\Users\Anupama Jadhav\Downloads\Loyalty of Employees\Loyall\Predict Loyall\employee_satisfaction_evaluation.xlsx')

# %%
s_df
# Out:
#        EMPLOYEE #  satisfaction_level  last_evaluation
# 0            1003                0.38             0.53
# 1            1005                0.80             0.86
# 2            1486                0.11             0.88
# 3            1038                0.72             0.87
# 4            1057                0.37             0.52
# ...           ...                 ...              ...
# 14994       87670                0.40             0.57
# 14995       87673                0.37             0.48
# 14996       87679                0.37             0.53
# 14997       87681                0.11             0.96
# 14998       87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %% [markdown]
# # Numerical Analysis

# %% [markdown]
# ### Merging and Joining

# %%
main_df = hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))

# %%
main_df                    # Here , empolyee_id has not been counted in columns......To solve this problem , we will use reset_index
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
# ...                     ...                   ...                 ...
# 87670                     2                   151                   3
# 87673                     2                   160                   3
# 87679                     2                   143                   3
# 87681                     6                   280                   4
# 87684                     2                   158                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# 1003                     0     1                      0      sales     low
# 1005                     0     1                      0      sales  medium
# 1486                     0     1                      0      sales  medium
# 1038                     0     1                      0      sales     low
# 1057                     0     1                      0      sales     low
# ...                    ...   ...                    ...        ...     ...
# 87670                    0     1                      0    support     low
# 87673                    0     1                      0    support     low
# 87679                    0     1                      0    support     low
# 87681                    0     1                      0    support     low
# 87684                    0     1                      0    support     low
#
#              satisfaction_level  last_evaluation
# employee_id
# 1003                       0.38             0.53
# 1005                       0.80             0.86
# 1486                       0.11             0.88
# 1038                       0.72             0.87
# 1057                       0.37             0.52
# ...                         ...              ...
# 87670                      0.40             0.57
# 87673                      0.37             0.48
# 87679                      0.37             0.53
# 87681                      0.11             0.96
# 87684                      0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df = main_df.reset_index()

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 11 columns]

# %%
 main_df.info()            # In this main_df, we have 27 rows of null values( ie. Missing values) in satisfaction_level and last_evaluation columns.......
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
main_df[main_df.isnull().any(axis = 1)]               # This will show those 27 rows which contains null values......Here, axis = 1 means rows and axis = 0 means columns
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# 352           3150               4                   262                   6
# 376           3250               4                   296                   2
# 402           3405               5                   275                   5
# 427          78130               3                   180                   4
# 442           3635               5                   229                   5
# 468           3755               5                   245                   5
# 543           4150               5                   237                   5
# 892          43615               4                   276                   5
# 1588         42185               5                   264                   5
# 1934         11895               4                   225                   5
# 2343         14170               3                   115                   2
# 2743         16445               5                   149                   2
# 3170         18980               5                   186                   2
# 3609         21580               3                   263                   2
# 3776         22555               4                   214                   3
# 4122         24505               3                   192                   3
# 4740         27950               3                   253                   3
# 5028         29640               4                   180                   4
# 6453         38090               5                   166                   2
# 7005         41535               4                   150                   3
# 7516         44460               4                   264                   3
# 8630         50960               4                   167                   3
# 9455         55770               4                   270                   3
# 9901         58630               5                   252                   3
# 10647        62595               4                   165                   3
# 10962        64350               5                   233                   3
# 11575        20215               3                   192                   7
# 11967        70005               3                   148                   3
# 12422        72475               5                   257                   5
# 12853        74880               3                   136                   2
# 13482        78780               3                   207                   7
# 13925        81315               3                   133                   3
#
#        Work_accident  left  promotion_last_5years   department  salary  \
# 18                 1     1                      1        sales     low
# 19                 0     1                      0        sales     low
# 33                 0     1                      0           hr     low
# 53                 0     1                      0      support     low
# 72                 0     1                      0  product_mng    high
# 92                 0     1                      0        sales     low
# 107                0     1                      0   accounting  medium
# 120                1     1                      0    technical     low
# 137                0     1                      0   management     low
# 175                0     1                      0        sales     low
# 191                1     1                      0    technical  medium
# 352                0     1                      0      support     low
# 376                0     1                      0           IT  medium
# 402                0     1                      0        sales     low
# 427                0     1                      0    technical  medium
# 442                0     1                      0   management     low
# 468                0     1                      0        sales     low
# 543                0     1                      0        sales  medium
# 892                0     1                      0      support     low
# 1588               0     1                      0           IT  medium
# 1934               0     1                      0        sales  medium
# 2343               1     0                      0      support     low
# 2743               0     0                      0        RandD     low
# 3170               0     0                      0    technical  medium
# 3609               1     0                      0        sales  medium
# 3776               0     0                      0    technical  medium
# 4122               0     0                      0    marketing    high
# 4740               0     0                      0    marketing  medium
# 5028               0     0                      0  product_mng  medium
# 6453               0     0                      0    technical    high
# 7005               0     0                      0    technical     low
# 7516               0     0                      0    technical     low
# 8630               1     0                      0    technical     low
# 9455               0     0                      0  product_mng     low
# 9901               0     0                      0      support  medium
# 10647              0     0                      0    technical     low
# 10962              0     0                      0      support     low
# 11575              0     0                      0   management    high
# 11967              0     0                      0           IT     low
# 12422              0     1                      0    technical  medium
# 12853              0     0                      0           hr    high
# 13482              0     0                      1   management  medium
# 13925              0     0                      0        sales  medium
#
#        satisfaction_level  last_evaluation
# 18                    NaN              NaN
# 19                    NaN             0.89
# 33                    NaN              NaN
# 53                    NaN              NaN
# 72                    NaN              NaN
# 92                    NaN              NaN
# 107                   NaN              NaN
# 120                   NaN              NaN
# 137                   NaN              NaN
# 175                   NaN              NaN
# 191                  0.92              NaN
# 352                   NaN             0.91
# 376                  0.56              NaN
# 402                   NaN             1.00
# 427                   NaN             0.60
# 442                  0.77              NaN
# 468                   NaN             0.92
# 543                  0.89              NaN
# 892                  0.74              NaN
# 1588                  NaN             0.81
# 1934                 0.78              NaN
# 2343                  NaN             0.97
# 2743                 0.62              NaN
# 3170                  NaN              NaN
# 3609                 0.95              NaN
# 3776                  NaN             0.68
# 4122                 0.86              NaN
# 4740                  NaN             0.95
# 5028                 0.64              NaN
# 6453                  NaN             0.78
# 7005                 0.82              NaN
# 7516                  NaN             0.97
# 8630                 0.90              NaN
# 9455                  NaN             0.88
# 9901                 0.92              NaN
# 10647                 NaN             0.69
# 10962                0.65              NaN
# 11575                 NaN              NaN
# 11967                0.82              NaN
# 12422                 NaN             1.00
# 12853                 NaN             0.70
# 13482                0.58              NaN
# 13925                 NaN             0.75

# %%
main_df.isnull().sum()               # This shows us very clearly that which all columns contains Null values
# Out:
# employee_id               0
# number_project            0
# average_montly_hours      0
# time_spend_company        0
# Work_accident             0
# left                      0
# promotion_last_5years     0
# department                0
# salary                    0
# satisfaction_level       27
# last_evaluation          27
# dtype: int64

# %%
# Now we have 2 options : 1) Either drop those rows which contains Null values (Not Recommended .....because by doing this we may loose many important informations)
#                         2) Fill up those Null values      ( So....its always better to fill up those Null values)

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# std         0.351719      0.425924               0.144281            0.248714
# min         0.000000      0.000000               0.000000            0.090000
# 25%         0.000000      0.000000               0.000000            0.440000
# 50%         0.000000      0.000000               0.000000            0.640000
# 75%         0.000000      0.000000               0.000000            0.820000
# max         1.000000      1.000000               1.000000            1.000000
#
#        last_evaluation
# count     14972.000000
# mean          0.716125
# std           0.171138
# min           0.360000
# 25%           0.560000
# 50%           0.720000
# 75%           0.870000
# max           1.000000

# %%
main_df.fillna(main_df.mean(), inplace=True)        # Here, we have replcace those Null values with Mean values (According to their columns).....and inplace=True means the changes that we have done are permanent.....

# %%
main_df.isnull().sum()                 # We can see that...... the Null values have successfully been replaced by their respective Mean values.....
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# satisfaction_level       0
# last_evaluation          0
# dtype: int64

# %%
main_df[main_df.isnull().any(axis=1)]           # Now there are no Null values
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
main_df.loc[main_df['employee_id'] == 3794]         # loc is label-based....we have to specify the name of the rows and columns that we need to filter out......
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 18         3794               2                   160                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 18              1     1                      1      sales    low
#
#     satisfaction_level  last_evaluation
# 18             0.61283         0.716125

# %%
main_df.loc[main_df['employee_id'] == 1140]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 19         1140               5                   262                   5
#
#     Work_accident  left  promotion_last_5years department salary  \
# 19              0     1                      0      sales    low
#
#     satisfaction_level  last_evaluation
# 19             0.61283             0.89

# %% [markdown]
# ### Droping Employee_id.....Because now we don't need it

# %%
main_df.drop(columns = 'employee_id', inplace = True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# RandD                  134   121                     27           487.80000
# accounting              96   204                     14           446.68283
# hr                      89   215                     15           442.53566
# management             103    91                     69           391.76566
# marketing              138   203                     43           530.62283
# product_mng            132   198                      0           559.19566
# sales                  587  1014                    100          2543.77981
# support                345   555                     20          1377.90849
# technical              381   697                     28          1653.37264
#
#              last_evaluation
# department
# IT                879.452250
# RandD             560.446125
# accounting        550.706125
# hr                524.006125
# management        456.234499
# marketing         613.946125
# product_mng       644.662250
# sales            2938.236749
# support          1611.534499
# technical        1961.930624

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# RandD             0.170267  0.153748               0.034307
# accounting        0.125163  0.265971               0.018253
# hr                0.120433  0.290934               0.020298
# management        0.163492  0.144444               0.109524
# marketing         0.160839  0.236597               0.050117
# product_mng       0.146341  0.219512               0.000000
# sales             0.141787  0.244928               0.024155
# support           0.154778  0.248991               0.008973
# technical         0.140074  0.256250               0.010294
#
#              satisfaction_level  last_evaluation
# department
# IT                     0.617908         0.716750
# RandD                  0.619822         0.712130
# accounting             0.582377         0.718000
# hr                     0.598830         0.709075
# management             0.621850         0.724182
# marketing              0.618442         0.715555
# product_mng            0.619951         0.714703
# sales                  0.614440         0.709719
# support                0.618173         0.722985
# technical              0.607858         0.721298

# %%
main_df['department'].value_counts()                     # This data shows how many employees are working in the different departments.....
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df['left'].value_counts()               # This data shows that total 3571 employees have quit their jobs......
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# #  Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_corr(df, size = 10):
    corr = df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
plot_corr(main_df)
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(x = main_df['left'], height=main_df['satisfaction_level'])
# Out:
# <BarContainer object of 14999 artists>

# %%
sns.barplot(x = 'left', y = 'satisfaction_level', data = main_df)       # Seaborn is better for data visualization....... Here, 0 means not left and 1 means left the company

# %%
sns.barplot(x = 'promotion_last_5years', y = 'satisfaction_level', data = main_df)

# %% [markdown]
# # #Data Preprocessing

# %%
main_df[['department', 'salary']]
# Out:
#        department  salary
# 0               7       1
# 1               7       2
# 2               7       2
# 3               7       1
# 4               7       1
# ...           ...     ...
# 14994           8       1
# 14995           8       1
# 14996           8       1
# 14997           8       1
# 14998           8       1
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
main_df['salary'] = le.fit_transform(main_df['salary'])

# %%
main_df                      # Here, we have successfully encoded the salary column
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  department  salary  \
# 0                  0     1                      0           7       1
# 1                  0     1                      0           7       2
# 2                  0     1                      0           7       2
# 3                  0     1                      0           7       1
# 4                  0     1                      0           7       1
# ...              ...   ...                    ...         ...     ...
# 14994              0     1                      0           8       1
# 14995              0     1                      0           8       1
# 14996              0     1                      0           8       1
# 14997              0     1                      0           8       1
# 14998              0     1                      0           8       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['salary'].unique()         # Here, low = 1, medium = 2 and high = 0
# Out:
# array([1, 2, 0], dtype=int64)

# %%
main_df['department'] = le.fit_transform(main_df['department'])

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  department  salary  \
# 0                  0     1                      0           7       1
# 1                  0     1                      0           7       2
# 2                  0     1                      0           7       2
# 3                  0     1                      0           7       1
# 4                  0     1                      0           7       1
# ...              ...   ...                    ...         ...     ...
# 14994              0     1                      0           8       1
# 14995              0     1                      0           8       1
# 14996              0     1                      0           8       1
# 14997              0     1                      0           8       1
# 14998              0     1                      0           8       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['department'].unique()
# Out:
# array([7, 2, 3, 9, 8, 4, 0, 6, 5, 1], dtype=int64)

# %% [markdown]
# # Spliting our data into training and testing phase

# %%
x = main_df.drop(['left'], axis=1)
y = main_df['left']

# %%
x
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  department  salary  \
# 0                  0                      0           7       1
# 1                  0                      0           7       2
# 2                  0                      0           7       2
# 3                  0                      0           7       1
# 4                  0                      0           7       1
# ...              ...                    ...         ...     ...
# 14994              0                      0           8       1
# 14995              0                      0           8       1
# 14996              0                      0           8       1
# 14997              0                      0           8       1
# 14998              0                      0           8       1
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 9 columns]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,)
scores_dict = {}

# %%
x_train
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 3001                5                   227                   3
# 10634               4                   230                   3
# 5687                4                   134                   4
# 6264                2                   206                   2
# 693                 6                   278                   4
# ...               ...                   ...                 ...
# 3625                3                   245                   3
# 12324               2                   131                   3
# 11999               4                   180                   3
# 6931                3                   188                   5
# 7564                2                   129                   5
#
#        Work_accident  promotion_last_5years  department  salary  \
# 3001               1                      0           7       2
# 10634              0                      0           7       0
# 5687               0                      0           9       1
# 6264               0                      0           5       1
# 693                0                      0           5       2
# ...              ...                    ...         ...     ...
# 3625               1                      0           9       1
# 12324              0                      0           7       1
# 11999              0                      0           0       1
# 6931               0                      0           0       1
# 7564               0                      0           5       2
#
#        satisfaction_level  last_evaluation
# 3001                 0.66             0.75
# 10634                0.56             0.99
# 5687                 0.52             0.77
# 6264                 0.49             0.96
# 693                  0.10             0.83
# ...                   ...              ...
# 3625                 0.59             0.90
# 12324                0.37             0.45
# 11999                0.50             0.73
# 6931                 0.61             0.67
# 7564                 0.95             0.90
#
# [10499 rows x 9 columns]

# %%
x_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 5304                4                   264                   3
# 8964                4                   128                   6
# 10560               2                   238                   3
# 5085                3                   149                   2
# 8325                3                   201                   2
# ...               ...                   ...                 ...
# 13800               3                   135                   7
# 3221                5                   182                   3
# 11405               3                   238                   4
# 13329               2                   125                   4
# 3458                4                   216                   3
#
#        Work_accident  promotion_last_5years  department  salary  \
# 5304               0                      0           9       1
# 8964               0                      0           3       2
# 10560              0                      0           2       1
# 5085               0                      0           8       2
# 8325               0                      0           9       1
# ...              ...                    ...         ...     ...
# 13800              0                      0           7       2
# 3221               0                      0           7       2
# 11405              0                      1           5       2
# 13329              1                      0           7       1
# 3458               0                      0           7       2
#
#        satisfaction_level  last_evaluation
# 5304                 0.69             0.83
# 8964                 0.53             0.94
# 10560                0.92             0.40
# 5085                 0.72             0.63
# 8325                 0.61             0.89
# ...                   ...              ...
# 13800                0.78             0.80
# 3221                 0.63             0.70
# 11405                0.60             0.62
# 13329                0.49             1.00
# 3458                 0.74             0.50
#
# [4500 rows x 9 columns]

# %%
y_train
# Out:
# 3001     0
# 10634    0
# 5687     0
# 6264     0
# 693      1
#         ..
# 3625     0
# 12324    1
# 11999    0
# 6931     0
# 7564     0
# Name: left, Length: 10499, dtype: int64

# %%
y_test
# Out:
# 5304     0
# 8964     0
# 10560    0
# 5085     0
# 8325     0
#         ..
# 13800    0
# 3221     0
# 11405    0
# 13329    0
# 3458     0
# Name: left, Length: 4500, dtype: int64

# %%
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # Model Training

# %% [markdown]
# ## 1: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
prediction_dt = dt.predict(x_test)
accuracy_dt = accuracy_score(y_test, prediction_dt) * 100

# %%
print('Accuracy Score :', accuracy_dt)
scores_dict['DecisionTreeClassifier'] = accuracy_dt
print(classification_report(y_test,prediction_dt))
# Out:
# Accuracy Score : 97.53333333333333
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      3443
#            1       0.93      0.96      0.95      1057
#
#     accuracy                           0.98      4500
#    macro avg       0.96      0.97      0.97      4500
# weighted avg       0.98      0.98      0.98      4500

# %% [markdown]
# ## Testing your own data

# %%
Catagory=['Employee will stay','Employee will Leave']

# %%
custom_dt = [[1,500,3,6,0,0.90,0.89,0.23,0.89]]

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will stay'

# %%
custom_dt2 = [[4, 135, 2, 1, 0, 4, 2, 0.89, 0.62]]

# %%
Catagory[int(dt.predict(custom_dt2))]
# Out:
# 'Employee will stay'

# %% [markdown]
# # Finding out the most important parameter

# %%
dt.feature_importances_
# Out:
# array([1.11329686e-01, 9.43254285e-02, 1.44856838e-01, 1.86994713e-03,
#        6.15076261e-05, 8.89264684e-03, 4.17708659e-03, 4.84067927e-01,
#        1.50418932e-01])

# %%
feature_importance = pd.DataFrame(dt.feature_importances_, index = x_train.columns, columns = ['Importance']).sort_values('Importance', ascending=False)

# %% [markdown]
# ## 2: KNN

# %%
from sklearn.preprocessing import StandardScaler      # StandardScaler is use to standardised your data in a particular range......Because, in KNN we have to calculate the distance....so it is always recommended to standardised your data......
sc = StandardScaler().fit(x_train)                    # Here, fit is used analyse the pattern 
x_train_std = sc.transform(x_train)                   # After analysing the pattern, it will transform the data accordingly
x_test_std = sc.transform(x_test)

# %%
x_train_std                              # Now the data has been scaled in a particular range
# Out:
# array([[ 0.97767421,  0.52482041, -0.34102929, ...,  1.05667126,
#          0.18474204,  0.20656709],
#        [ 0.16572978,  0.58471811, -0.34102929, ..., -2.14228825,
#         -0.21853803,  1.60883665],
#        [ 0.16572978, -1.33200837,  0.34712495, ..., -0.54280849,
#         -0.37985005,  0.32342289],
#        ...,
#        [ 0.16572978, -0.41357693, -0.34102929, ..., -0.54280849,
#         -0.46050607,  0.0897113 ],
#        [-0.64621466, -0.25384972,  1.0352792 , ..., -0.54280849,
#         -0.01689799, -0.26085609],
#        [-1.45815909, -1.43183787,  1.0352792 , ...,  1.05667126,
#          1.35425424,  1.08298557]])

# %%
x_test_std
# Out:
# array([[ 0.16572978,  1.26355874, -0.34102929, ..., -0.54280849,
#          0.30572606,  0.67399028],
#        [ 0.16572978, -1.45180377,  1.72343344, ...,  1.05667126,
#         -0.33952205,  1.31669716],
#        [-1.45815909,  0.74444532, -0.34102929, ..., -0.54280849,
#          1.23327022, -1.83840934],
#        ...,
#        [-0.64621466,  0.74444532,  0.34712495, ...,  1.05667126,
#         -0.057226  , -0.55299558],
#        [-1.45815909, -1.51170148,  0.34712495, ..., -0.54280849,
#         -0.50083407,  1.66726455],
#        [ 0.16572978,  0.3051955 , -0.34102929, ...,  1.05667126,
#          0.5073661 , -1.25413036]])

# %%
from sklearn.neighbors import KNeighborsClassifier

k_range=range(3,26)
scores={}
scores_list=[]
bestk=0
h_score = 0

for i in range(3,26):
    clf = KNeighborsClassifier(n_neighbors=i).fit(x_train_std,y_train)
    pred = clf.predict(x_test_std)
    scores[i]=accuracy_score(y_test,pred)
    if scores[i]>h_score:
        h_score = scores[i]
        bestk = i
    scores_list.append(scores[i])
print('Best k is {} with score : {}'.format(bestk,h_score))
# Out:
# Best k is 3 with score : 0.9617777777777777

# %%
knn=KNeighborsClassifier(n_neighbors=bestk)
knn.fit(x_train_std,y_train)
prediction_knn=knn.predict(x_test_std)
accuracy_knn=accuracy_score(y_test,prediction_knn)*100

# %%
print('Accuracy score : ',accuracy_knn)
scores_dict['KNeighborsClassifier'] = accuracy_score(y_test,prediction_knn)*100
print(classification_report(y_test,prediction_knn))
# Out:
# Accuracy score :  96.17777777777778
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      3443
#            1       0.91      0.93      0.92      1057
#
#     accuracy                           0.96      4500
#    macro avg       0.94      0.95      0.95      4500
# weighted avg       0.96      0.96      0.96      4500

# %%
plt.plot(k_range,scores_list)

# %%
algorithms = ['Decision Tree', 'KNN']        # As we can see, Decision Tree works better as compared to KNN
scores = [accuracy_dt, accuracy_knn]
plt.xlabel('Algorithms')
plt.ylabel('Accuracy')
sns.barplot(algorithms, scores)
plt.show()
